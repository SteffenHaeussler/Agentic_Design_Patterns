# %%
import os
import asyncio
from typing import Optional

from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import Runnable, RunnableParallel, RunnablePassthrough

# %%
# --- Configuration ---
# Ensure your API key environment variable is set (e.g., OPENAI_API_KEY)
try:
    llm: Optional[ChatOpenAI] = ChatOpenAI(model="gpt-4o-mini", temperature=0.7)
    if llm:
        print(f"Language model initialized: {llm.model_name}")
except Exception as e:
    print(f"Error initializing language model: {e}")
    llm = None


# --- Define Independent Chains ---
# These three chains represent distinct tasks that can be executed in parallel.

summarize_chain: Runnable = (
    ChatPromptTemplate.from_messages([
        ("system", "Summarize the following topic concisely:"),
        ("user", "{topic}")
    ])
    | llm
    | StrOutputParser()
)

questions_chain: Runnable = (
    ChatPromptTemplate.from_messages([
        ("system", "Generate three interesting questions about the following topic:"),
        ("user", "{topic}")
    ])
    | llm
    | StrOutputParser()
)

terms_chain: Runnable = (
    ChatPromptTemplate.from_messages([
        ("system", "Identify 5-10 key terms from the following topic, separated by commas:"),
        ("user", "{topic}")
    ])
    | llm
    | StrOutputParser()
)
# Out:
# Language model initialized: gpt-4o-mini

# %%
# --- Build the Parallel + Synthesis Chain ---

# 1. Define the block of tasks to run in parallel. The results of these,
#    along with the original topic, will be fed into the next step.
map_chain = RunnableParallel(
    {
        "summary": summarize_chain,
        "questions": questions_chain,
        "key_terms": terms_chain,
        "topic": RunnablePassthrough(),  # Pass the original topic through
    }
)

# 2. Define the final synthesis prompt which will combine the parallel results.
synthesis_prompt = ChatPromptTemplate.from_messages([
    ("system", """Based on the following information:
     Summary: {summary}
     Related Questions: {questions}
     Key Terms: {key_terms}
     Synthesize a comprehensive answer."""),
    ("user", "Original topic: {topic}")
])

# 3. Construct the full chain by piping the parallel results directly
#    into the synthesis prompt, followed by the LLM and output parser.
full_parallel_chain = map_chain | synthesis_prompt | llm | StrOutputParser()

# %%
# --- Run the Chain ---
async def run_parallel_example(topic: str) -> None:
    """
    Asynchronously invokes the parallel processing chain with a specific topic
    and prints the synthesized result.

    Args:
        topic: The input topic to be processed by the LangChain chains.
    """
    if not llm:
        print("LLM not initialized. Cannot run example.")
        return

    print(f"\n--- Running Parallel LangChain Example for Topic: '{topic}' ---")
    try:
        # The input to `ainvoke` is the single 'topic' string, which is
        # then passed to each runnable in the `map_chain`.
        response = await full_parallel_chain.ainvoke(topic)
        print("\n--- Final Response ---")
        print(response)
    except Exception as e:
        print(f"\nAn error occurred during chain execution: {e}")

# %%
test_topic = "The history of space exploration"
    # In Python 3.7+, asyncio.run is the standard way to run an async function.
await run_parallel_example(test_topic)
# Out:
# --- Running Parallel LangChain Example for Topic: 'The history of space exploration' ---
#
# --- Final Response ---
# The history of space exploration is a narrative marked by significant milestones and technological advancements, driven by both scientific curiosity and geopolitical competition. It can be divided into several key phases:
#
# 1. **Early Observations and Theories**: The journey began with ancient astronomers who made observations of celestial bodies and developed theories about the universe, laying the groundwork for future exploration. Notable figures such as Galileo and Kepler contributed to our understanding of planetary motion and the structure of the solar system.
#
# 2. **The Space Age and Cold War Rivalry**: The launch of Sputnik by the Soviet Union in 1957 is heralded as the dawn of the Space Age. This event not only demonstrated the capability to send objects into orbit but also intensified the Cold War rivalry between the United States and the Soviet Union. The competition spurred rapid advancements in space technology, leading to milestones such as Yuri Gagarin's historic flight in 1961, which made him the first human to orbit Earth. In response, the U.S. launched the Apollo program, culminating in the iconic Moon landing in 1969, where astronauts Neil Armstrong and Buzz Aldrin became the first humans to set foot on another celestial body.
#
# 3. **Post-Apollo Developments**: After the Moon landings, space exploration continued to evolve with the establishment of space stations like Mir and the International Space Station (ISS), which facilitated international collaboration in research and experimentation in microgravity. The era also saw the rise of robotic missions, with space probes and landers exploring planets and moons within our solar system. Notable missions include the Voyager probes, which provided invaluable data about the outer planets, and the Mars rovers, which continue to explore the Martian surface.
#
# 4. **Advancements in Technology and International Cooperation**: Since 1969, technological advancements have transformed space exploration. The development of more sophisticated spacecraft and launch systems, alongside the integration of advanced robotics and artificial intelligence, has expanded our capabilities. International collaboration has also become a cornerstone of modern space exploration, exemplified by partnerships on the ISS, joint missions, and shared scientific objectives.
#
# 5. **Private Sector Involvement and Future Prospects**: In recent years, the emergence of private companies like SpaceX and Blue Origin has revolutionized the landscape of space exploration. These companies have significantly reduced costs and increased access to space, paving the way for commercial spaceflight and potential colonization efforts on other planets, particularly Mars. The involvement of the private sector not only fosters innovation but also encourages a more diverse range of missions and objectives, including space tourism and asteroid mining.
#
# Overall, the history of space exploration reflects humanity's relentless pursuit of knowledge and our desire to understand our place in the universe. Each milestone has not only expanded our scientific understanding but has also led to technological advancements that have had profound impacts on life on Earth. As we look to the future, the combination of international cooperation and private sector innovation promises to further propel space exploration into uncharted territories.
