# %%
from google.adk.agents import Agent
from google.adk.runners import Runner
from google.adk.sessions import InMemorySessionService
from google.adk.tools import google_search
from google.genai import types
import nest_asyncio
import asyncio

# Define variables required for Session setup and Agent execution
APP_NAME="Google Search_agent"
USER_ID="user1234"
SESSION_ID="1234"

# %%
# Define Agent with access to search tool
root_agent = Agent(
   name="basic_search_agent",
   model="gemini-2.5-flash-lite",
   description="Agent to answer questions using Google Search.",
   instruction="I can answer your questions by searching the internet. Just ask me anything!",
   tools=[google_search] # Google Search is a pre-built tool to perform Google searches.
)

# %%
# Agent Interaction
async def call_agent(query):
   """
   Helper function to call the agent with a query.
   """

   # Session and Runner
   session_service = InMemorySessionService()
   session = await session_service.create_session(app_name=APP_NAME, user_id=USER_ID, session_id=SESSION_ID)
   runner = Runner(agent=root_agent, app_name=APP_NAME, session_service=session_service)

   content = types.Content(role='user', parts=[types.Part(text=query)])
   events = runner.run(user_id=USER_ID, session_id=SESSION_ID, new_message=content)


   for event in events:
       if event.is_final_response():
           final_response = event.content.parts[0].text
           print("Agent Response: ", final_response)

# %%
nest_asyncio.apply()

asyncio.run(call_agent("what's the latest ai news?"))
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# Agent Response:  Recent AI news highlights significant advancements and strategic shifts across various industries. Meta has unveiled four new generations of custom AI chips, aiming to reduce its reliance on Nvidia and improve efficiency in its data centers. Ford has launched "Ford Pro AI," an AI assistant for its commercial vehicle telematics platform that analyzes over a billion data points daily to optimize fleet management. In the realm of healthcare, a UCSF study found that generative AI can match human expert teams in analyzing complex medical data, potentially accelerating biomedical research.
#
# OpenAI has reportedly put the release of its ChatGPT adult mode on hold and is also scaling back its AI video platform, Sora, to focus on advanced AI and robotics. Apple has announced that an AI-powered Siri will debut in 2026, featuring on-screen awareness and cross-app integration.
#
# Furthermore, global leaders are convening at the Global AI Future Summit in New Delhi to discuss AI governance, safety, and equitable distribution of its benefits. In robotics, Hyundai Motor Group is detailing its "AI+Robotics" roadmap to lead in human-centered robotics. MIT researchers have developed a new AI model that could significantly reduce the costs of developing protein-based drugs.
#
# Google is also making strides, with updates on its Lyria music generation models and improvements to Gemini in Google Sheets. They are also officially entering the industrial robotics AI market and are focused on bringing "Personal Intelligence" to more people through Search.
#
# The broader trends in AI include breakthroughs in generative AI and large language models, the increasing application of AI in engineering, and the growing importance of machine learning in automation. There's also a focus on ethical AI and the role of human oversight. The pace of AI innovation is accelerating, driven by increased computational power, larger training datasets, and algorithmic advancements. Edge computing is also gaining traction for real-time AI applications.
