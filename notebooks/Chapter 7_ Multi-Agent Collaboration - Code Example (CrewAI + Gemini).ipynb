# %%
import os
from dotenv import load_dotenv
from crewai import Agent, Task, Crew, Process
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
def setup_environment():
    """Loads environment variables and checks for the required API key."""
    load_dotenv()
    if not os.getenv("GOOGLE_API_KEY"):
        raise ValueError("GOOGLE_API_KEY not found. Please set it in your .env file.")

# %%
def main():
    """
    Initializes and runs the AI crew for content creation using the latest Gemini model.
    """
    setup_environment()

    # Define the language model to use.
    # Updated to a model from the Gemini 2.0 series for better performance and features.
    # For cutting-edge (preview) capabilities, you could use "gemini-2.5-flash".
    llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

    # Define Agents with specific roles and goals
    researcher = Agent(
        role='Senior Research Analyst',
        goal='Find and summarize the latest trends in AI.',
        backstory="You are an experienced research analyst with a knack for identifying key trends and synthesizing information.",
        verbose=True,
        allow_delegation=False,
    )

    writer = Agent(
        role='Technical Content Writer',
        goal='Write a clear and engaging blog post based on research findings.',
        backstory="You are a skilled writer who can translate complex technical topics into accessible content.",
        verbose=True,
        allow_delegation=False,
    )

    # Define Tasks for the agents
    research_task = Task(
        description="Research the top 3 emerging trends in Artificial Intelligence in 2024-2025. Focus on practical applications and potential impact.",
        expected_output="A detailed summary of the top 3 AI trends, including key points and sources.",
        agent=researcher,
    )

    writing_task = Task(
        description="Write a 500-word blog post based on the research findings. The post should be engaging and easy for a general audience to understand.",
        expected_output="A complete 500-word blog post about the latest AI trends.",
        agent=writer,
        context=[research_task],
    )

    # Create the Crew
    blog_creation_crew = Crew(
        agents=[researcher, writer],
        tasks=[research_task, writing_task],
        process=Process.sequential,
        llm=llm,
        verbose=True # Set verbosity for detailed crew execution logs
    )

    # Execute the Crew
    print("## Running the blog creation crew with Gemini 2.0 Flash... ##")
    try:
        result = blog_creation_crew.kickoff()
        print("\n------------------\n")
        print("## Crew Final Output ##")
        print(result)
    except Exception as e:
        print(f"\nAn unexpected error occurred: {e}")

# %%
if __name__ == "__main__":
    main()
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# ## Running the blog creation crew with Gemini 2.0 Flash... ##
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: a1a5eaf6-567a-4896-9e66-b0bf93a2be83                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Senior Research Analyst                                                                                 │
# │                                                                                                                 │
# │  Task: Research the top 3 emerging trends in Artificial Intelligence in 2024-2025. Focus on practical           │
# │  applications and potential impact.                                                                             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 328062ae-543f-4b08-8555-349779a32dc5                                                                     │
# │  Agent: Senior Research Analyst                                                                                 │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Technical Content Writer                                                                                │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **Top 3 Emerging AI Trends in 2024-2025: Transforming Our World**                                              │
# │                                                                                                                 │
# │  Artificial Intelligence (AI) continues to evolve at a breakneck pace, reshaping industries and the way we      │
# │  live and work. As we move further into 2024 and look ahead to 2025, three key AI trends are emerging as game   │
# │  changers: Generative AI, AI-powered autonomous systems and robotics, and explainable and trustworthy AI for    │
# │  critical decision-making. These trends don’t just represent technical advancements, but practical shifts       │
# │  promising immense impact across sectors.                                                                       │
# │                                                                                                                 │
# │  ### 1. Generative AI: Revolutionizing Creativity and Industry                                                  │
# │                                                                                                                 │
# │  Generative AI—the technology behind large language models (LLMs) and generative adversarial networks           │
# │  (GANs)—has rapidly matured, powering an array of practical applications. Whether it’s crafting text,           │
# │  designing images, generating videos, or writing computer code, generative AI tools are democratizing           │
# │  creativity and skills once limited to experts.                                                                 │
# │                                                                                                                 │
# │  Businesses are employing AI-assisted content creation to streamline marketing campaigns, automate routine      │
# │  design work, and accelerate software development with code generation tools. Synthetic data generation is      │
# │  another exciting breakthrough, enabling AI models to train on rich datasets without compromising privacy. The  │
# │  result? Dramatic productivity gains and the ability for individuals and organizations to innovate faster.      │
# │  Companies like OpenAI, Adobe, and NVIDIA are investing heavily in improving these AI models’ contextual        │
# │  understanding and safety to reduce risks like misinformation and bias.                                         │
# │                                                                                                                 │
# │  However, this transformation brings challenges in content authenticity and intellectual property,              │
# │  necessitating new frameworks for ethical use and regulation. Still, the evolving landscape is reshaping        │
# │  creative workflows and upending traditional content production industries worldwide.                           │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### 2. AI-Powered Autonomous Systems and Robotics: Automating the Physical World                               │
# │                                                                                                                 │
# │  Another thrilling arena is the fusion of AI with robotics, enabling smarter autonomous systems deployed in     │
# │  logistics, manufacturing, agriculture, and mobility. Autonomous delivery robots, drones, and warehouse         │
# │  automation are becoming commercially viable tools, helping businesses cut costs while boosting speed and       │
# │  efficiency.                                                                                                    │
# │                                                                                                                 │
# │  Powered by real-time sensor fusion, reinforcement learning, and adaptive control algorithms, these robots can  │
# │  navigate complex, unstructured environments safely. Autonomous vehicles continue to make strides too,          │
# │  boasting improved partial and full autonomy features supported by advanced AI interpreting vast sensor data.   │
# │  Governments and industry leaders are working closely to set safety standards and testing protocols, aiming to  │
# │  broaden adoption while keeping people safe.                                                                    │
# │                                                                                                                 │
# │  The impact? Supply chains are becoming faster and less expensive, hazardous industrial environments safer,     │
# │  and productivity higher. This trend also stirs debate around workforce disruption since automation could       │
# │  displace some jobs even as it unleashes new opportunities in AI and robotics careers. Meanwhile,               │
# │  infrastructure and regulatory questions loom large, especially for autonomous vehicles and drones operating    │
# │  in public spaces.                                                                                              │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### 3. Explainable and Trustworthy AI: Building Confidence in Critical Decisions                               │
# │                                                                                                                 │
# │  As AI systems increasingly influence high-stakes areas—think healthcare diagnoses, financial credit scoring,   │
# │  and legal rulings—the demand for transparency and trustworthiness has never been greater. Explainable AI       │
# │  (XAI) tackles this by developing models and techniques that clearly explain how AI reaches its decisions,      │
# │  empowering human oversight and enhancing accountability.                                                       │
# │                                                                                                                 │
# │  Initiatives focused on trustworthy AI emphasize fairness, mitigating bias, protecting data privacy, and        │
# │  defending against adversarial attacks that seek to deceive AI. Governments worldwide are rolling out           │
# │  regulations that require explainability and ethical deployment, shaping the future of AI governance.           │
# │  Embedding these principles into AI workflows improves acceptance and reliability in sensitive fields while     │
# │  reducing risks stemming from opaque or biased automated decisions.                                             │
# │                                                                                                                 │
# │  Beyond compliance, this fosters richer collaboration between AI technologists, domain experts, and             │
# │  policymakers—accelerating innovation rooted in ethical sensibilities.                                          │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Looking Ahead                                                                                              │
# │                                                                                                                 │
# │  The AI trends dominating 2024 and 2025 promise transformative impacts across industries and society.           │
# │  Generative AI is unlocking new realms of creativity and productivity; autonomous systems are reimagining our   │
# │  physical and operational world; explainable and trustworthy AI is laying the ethical foundation critical for   │
# │  broad acceptance.                                                                                              │
# │                                                                                                                 │
# │  Organizations that embrace these advances while thoughtfully addressing their challenges—ethical, legal, and   │
# │  societal—will be best positioned to thrive as AI moves deeper into daily life and business. The future with    │
# │  AI is not just about smarter machines, but smarter collaboration between humans and technology.                │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  *Sources: McKinsey & Company, Gartner, MIT Technology Review Insights, PwC, OpenAI Research Blog*              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 4bcd9b9d-52e5-48aa-888e-b630f82a8b06                                                                     │
# │  Agent: Technical Content Writer                                                                                │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
